# %%
import pandas as pd

# %%
df=pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]], columns=["A","B","C"])
df.head()  # give first five rows
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
df.head(2)
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6

# %%
df.head(1)
# Out:
#    A  B  C
# 0  1  2  3

# %%
df.tail(2)
# Out:
#    A  B  C
# 1  4  5  6
# 2  7  8  9

# %%
df
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
df=pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]], columns=["A","B","C"], index=["x","y","z"])
df
# Out:
#    A  B  C
# x  1  2  3
# y  4  5  6
# z  7  8  9

# %%
df.index
# Out:
# Index(['x', 'y', 'z'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, x to z
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       3 non-null      int64
#  2   C       3 non-null      int64
# dtypes: int64(3)
# memory usage: 96.0+ bytes

# %%
df.describe()
# Out:
#          A    B    C
# count  3.0  3.0  3.0
# mean   4.0  5.0  6.0
# std    3.0  3.0  3.0
# min    1.0  2.0  3.0
# 25%    2.5  3.5  4.5
# 50%    4.0  5.0  6.0
# 75%    5.5  6.5  7.5
# max    7.0  8.0  9.0

# %%
df.nunique()    # number of unique values in each column
# Out:
# A    3
# B    3
# C    3
# dtype: int64

# %%
df['A'].unique()   #gives unique values in a specific column
# Out:
# array([1, 4, 7], dtype=int64)

# %%
df.shape  # 3 ROWS AND 3 COLUMNS
# Out:
# (3, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, x to z
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       3 non-null      int64
#  2   C       3 non-null      int64
# dtypes: int64(3)
# memory usage: 204.0+ bytes

# %%
df.size   # number of cells
# Out:
# 9

# %%
coffee=pd.read_csv('coffee.csv')
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
results=pd.read_parquet('results.parquet')
results

# %%
olympic_data=pd.read_excel('olympics-data.xlsx', sheet_name="results")
olympic_data.head()

# %%
bios=pd.read_csv('bios.csv')

# %%
#coffee.to_csv
#coffee.to_parquet     to move to specific files
#coffee.to_excel

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
print(coffee)
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
display(coffee)
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee.head(10)
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35
# 5  Wednesday       Latte          25
# 6   Thursday    Espresso          40
# 7   Thursday       Latte          30
# 8     Friday    Espresso          45
# 9     Friday       Latte          35

# %%
coffee.tail(5)
# Out:
#          Day Coffee Type  Units Sold
# 9     Friday       Latte          35
# 10  Saturday    Espresso          45
# 11  Saturday       Latte          35
# 12    Sunday    Espresso          45
# 13    Sunday       Latte          35

# %%
coffee.sample(10,random_state=1)   # randomly select 10 rows/subset
#can also be used to select a random subset of columns
#random_state: A seed value for the random number generator. This ensures reproducibility of the sample.
# Out:
#           Day Coffee Type  Units Sold
# 3     Tuesday       Latte          20
# 7    Thursday       Latte          30
# 6    Thursday    Espresso          40
# 2     Tuesday    Espresso          30
# 10   Saturday    Espresso          45
# 4   Wednesday    Espresso          35
# 1      Monday       Latte          15
# 12     Sunday    Espresso          45
# 0      Monday    Espresso          25
# 13     Sunday       Latte          35

# %%
#loc allows us to filter by rows and columns over our dataframe
#coffee.loc[rows,cols]
coffee.loc[0]
# Out:
# Day              Monday
# Coffee Type    Espresso
# Units Sold           25
# Name: 0, dtype: object

# %%
coffee.loc[[0,1,2]]
# Out:
#        Day Coffee Type  Units Sold
# 0   Monday    Espresso          25
# 1   Monday       Latte          15
# 2  Tuesday    Espresso          30

# %%
coffee.loc[0:3]
# Out:
#        Day Coffee Type  Units Sold
# 0   Monday    Espresso          25
# 1   Monday       Latte          15
# 2  Tuesday    Espresso          30
# 3  Tuesday       Latte          20

# %%
coffee.loc[5:12]
# Out:
#           Day Coffee Type  Units Sold
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45

# %%
coffee.loc[5:8,["Day","Units Sold"]]   #iloc is similar just it takes the index of columns
# Out:
#          Day  Units Sold
# 5  Wednesday          25
# 6   Thursday          40
# 7   Thursday          30
# 8     Friday          45

# %%
coffee.iloc[:,[0,2]]
# Out:
#           Day  Units Sold
# 0      Monday          25
# 1      Monday          15
# 2     Tuesday          30
# 3     Tuesday          20
# 4   Wednesday          35
# 5   Wednesday          25
# 6    Thursday          40
# 7    Thursday          30
# 8      Friday          45
# 9      Friday          35
# 10   Saturday          45
# 11   Saturday          35
# 12     Sunday          45
# 13     Sunday          35

# %%
coffee.iloc[0:5,[0,2]]
# Out:
#          Day  Units Sold
# 0     Monday          25
# 1     Monday          15
# 2    Tuesday          30
# 3    Tuesday          20
# 4  Wednesday          35

# %%
# notice with iloc the upper index is not inclusive whereas with .loc it was inclusive

# %%
# we can also make any column of dataframe as our row indexes
coffee.index=coffee["Day"]
coffee
# Out:
#                  Day Coffee Type  Units Sold
# Day
# Monday        Monday    Espresso          25
# Monday        Monday       Latte          15
# Tuesday      Tuesday    Espresso          30
# Tuesday      Tuesday       Latte          20
# Wednesday  Wednesday    Espresso          35
# Wednesday  Wednesday       Latte          25
# Thursday    Thursday    Espresso          40
# Thursday    Thursday       Latte          30
# Friday        Friday    Espresso          45
# Friday        Friday       Latte          35
# Saturday    Saturday    Espresso          45
# Saturday    Saturday       Latte          35
# Sunday        Sunday    Espresso          45
# Sunday        Sunday       Latte          35

# %%
#now we will have to access the rows using day names rather than numberical indexes
# coffee.loc[0:3]
coffee.loc["Monday":"Wednesday", "Units Sold"]
# Out:
# Day
# Monday       25
# Monday       15
# Tuesday      30
# Tuesday      20
# Wednesday    35
# Wednesday    25
# Name: Units Sold, dtype: int64

# %%
# nowwe are resetting the dataframe
coffee=pd.read_csv('coffee.csv')
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
#modifying dataframe values
coffee.loc[1,"Units Sold"]=10
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          10
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
#setting multiple values
coffee.loc[1:3,"Units Sold"]=10
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          10
# 2     Tuesday    Espresso          10
# 3     Tuesday       Latte          10
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
#another way to fetch\

# %%
coffee.at[0,"Units Sold"]
# cannot access multiple values 
#coffee.at[0:3, "Units Sold"] gives error
# Out:
# 25

# %%
# .iat also works with both numertical indexes
coffee.iloc[0,0]
# Out:
# 'Monday'

# %%
coffee["Day"]
# Out:
# 0        Monday
# 1        Monday
# 2       Tuesday
# 3       Tuesday
# 4     Wednesday
# 5     Wednesday
# 6      Thursday
# 7      Thursday
# 8        Friday
# 9        Friday
# 10     Saturday
# 11     Saturday
# 12       Sunday
# 13       Sunday
# Name: Day, dtype: object

# %%
# sorting data based on a specific column value
coffee.sort_values("Units Sold")
# Out:
#           Day Coffee Type  Units Sold
# 1      Monday       Latte          10
# 2     Tuesday    Espresso          10
# 3     Tuesday       Latte          10
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 7    Thursday       Latte          30
# 4   Wednesday    Espresso          35
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 6    Thursday    Espresso          40
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45

# %%
coffee.sort_values("Units Sold", ascending=False)
# Out:
#           Day Coffee Type  Units Sold
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45
# 6    Thursday    Espresso          40
# 4   Wednesday    Espresso          35
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 7    Thursday       Latte          30
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 1      Monday       Latte          10
# 2     Tuesday    Espresso          10
# 3     Tuesday       Latte          10

# %%
# sorting bases on multiple columns
coffee.sort_values(["Units Sold", "Coffee Type"], ascending=[0,1])
# Out:
#           Day Coffee Type  Units Sold
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45
# 6    Thursday    Espresso          40
# 4   Wednesday    Espresso          35
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 7    Thursday       Latte          30
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 2     Tuesday    Espresso          10
# 1      Monday       Latte          10
# 3     Tuesday       Latte          10

# %%
# iteration of fataframe using for loop
for index, row in coffee.iterrows():
    print(index)
    print(row["Units Sold"])
    print('\n\n')
# Out:
# 0
# 25
#
#
#
# 1
# 10
#
#
#
# 2
# 10
#
#
#
# 3
# 10
#
#
#
# 4
# 35
#
#
#
# 5
# 25
#
#
#
# 6
# 40
#
#
#
# 7
# 30
#
#
#
# 8
# 45
#
#
#
# 9
# 35
#
#
#
# 10
# 45
#
#
#
# 11
# 35
#
#
#
# 12
# 45
#
#
#
# 13
# 35

# %%
# but try to use buiultin pandas method
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios.tail()
# Out:
#         athlete_id                 name   born_date        born_city  \
# 145495      149222    Polina Luchnikova  2002-01-30            Serov
# 145496      149223  Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224      Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225       André Foussard  1899-05-19            Niort
# 145499      149814        Bill Phillips  1913-07-15     Dulwich Hill
#
#             born_region born_country        NOC  height_cm  weight_kg  \
# 145495       Sverdlovsk          RUS        ROC      167.0       61.0
# 145496           Moskva          RUS        ROC      168.0       65.0
# 145497      Arkhangelsk          RUS        ROC      163.0       55.0
# 145498      Deux-Sèvres          FRA     France      166.0        NaN
# 145499  New South Wales          AUS  Australia        NaN        NaN
#
#          died_date
# 145495         NaN
# 145496         NaN
# 145497         NaN
# 145498  1986-03-18
# 145499  2003-10-20

# %%
bios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   athlete_id    145500 non-null  int64
#  1   name          145500 non-null  object
#  2   born_date     143693 non-null  object
#  3   born_city     110908 non-null  object
#  4   born_region   110908 non-null  object
#  5   born_country  110908 non-null  object
#  6   NOC           145499 non-null  object
#  7   height_cm     106651 non-null  float64
#  8   weight_kg     102070 non-null  float64
#  9   died_date     33940 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 11.1+ MB

# %%
#filtering data
# conditional filteringn
bios.loc[bios['height_cm']>215,["name", "height_cm"]]
# Out:
#                          name  height_cm
# 5089       Viktor Pankrashkin      220.0
# 5583     Paulinho Villas Boas      217.0
# 5673           Gunther Behnke      221.0
# 5716                 Uwe Blab      218.0
# 5781           Tommy Burleson      223.0
# 5796            Andy Campbell      218.0
# 6223              Lars Hansen      216.0
# 6270              Hu Zhangbao      216.0
# 6409         Sergey Kovalenko      216.0
# 6420            Jānis Krūmiņš      218.0
# 6504              Luc Longley      220.0
# 6722         Shaquille O'Neal      216.0
# 6937           David Robinson      216.0
# 6978          Arvydas Sabonis      223.0
# 7074           Paulo da Silva      217.0
# 7188       Vladimir Tkachenko      220.0
# 7281         Stojko Vranković      217.0
# 7376      Eurelijus Žukauskas      218.0
# 52608         Aleksey Kazakov      217.0
# 82100           Frédéric Weis      218.0
# 89070                Yao Ming      226.0
# 89075          Roberto Dueñas      221.0
# ...

# %%
bios[bios['height_cm']>215][["name","height_cm"]]
# Out:
#                          name  height_cm
# 5089       Viktor Pankrashkin      220.0
# 5583     Paulinho Villas Boas      217.0
# 5673           Gunther Behnke      221.0
# 5716                 Uwe Blab      218.0
# 5781           Tommy Burleson      223.0
# 5796            Andy Campbell      218.0
# 6223              Lars Hansen      216.0
# 6270              Hu Zhangbao      216.0
# 6409         Sergey Kovalenko      216.0
# 6420            Jānis Krūmiņš      218.0
# 6504              Luc Longley      220.0
# 6722         Shaquille O'Neal      216.0
# 6937           David Robinson      216.0
# 6978          Arvydas Sabonis      223.0
# 7074           Paulo da Silva      217.0
# 7188       Vladimir Tkachenko      220.0
# 7281         Stojko Vranković      217.0
# 7376      Eurelijus Žukauskas      218.0
# 52608         Aleksey Kazakov      217.0
# 82100           Frédéric Weis      218.0
# 89070                Yao Ming      226.0
# 89075          Roberto Dueñas      221.0
# ...

# %%
bios[(bios['height_cm']>215) & (bios["born_country"]=="USA")]
# Out:
#         athlete_id              name   born_date  born_city     born_region  \
# 5781          5804    Tommy Burleson  1952-02-24  Crossnore  North Carolina
# 6722          6755  Shaquille O'Neal  1972-03-06     Newark      New Jersey
# 6937          6972    David Robinson  1965-08-06   Key West         Florida
# 123850      126093    Tyson Chandler  1982-10-02    Hanford      California
#
#        born_country            NOC  height_cm  weight_kg died_date
# 5781            USA  United States      223.0      102.0       NaN
# 6722            USA  United States      216.0      137.0       NaN
# 6937            USA  United States      216.0      107.0       NaN
# 123850          USA  United States      216.0      107.0       NaN

# %%
bios[bios['name'].str.contains("Keith | patrick", case=False)]
# Out:
#         athlete_id               name   born_date     born_city  \
# 1897          1907       Keith Hanlon  1966-09-01           NaN
# 3505          3517      Keith Wallace  1961-03-29       Preston
# 6228          6255      Keith Hartley  1940-10-15     Vancouver
# 8898          8946        Keith Mwila  1966-01-01           NaN
# 12053        12118       Keith Hervey  1898-11-03        Fulham
# ...            ...                ...         ...           ...
# 109900      111105  Keith Cumberpatch  1927-08-25  Christchurch
# 115973      117348    Keith Sanderson  1975-02-02      Plymouth
# 116580      117975  Elizabeth Patrick  1985-03-02     Melbourne
# 121749      123764      Jaele Patrick  1988-03-04      Lilydale
# 122121      124176     Keith Ferguson  1979-09-07          Sale
#
#              born_region born_country            NOC  height_cm  weight_kg  \
# 1897                 NaN          NaN        Ireland        NaN        NaN
# ...

# %%
#find athelets born in city which starts with a vowel
vowel_cities=bios[bios['born_city'].str.contains(r'^[AEIOUaeiou]', na=False)]
print(vowel_cities)
# Out:
#         athlete_id                     name   born_date       born_city  \
# 5                6        Nicolas Chatelain  1970-01-13          Amiens
# 10              11  Élie, Comte de Lastours  1874-08-12         Orgeval
# 17              18     Jean-Philippe Gatien  1968-10-16            Alès
# 35              36          Étienne Thobois  1967-09-20          Amiens
# 40              41           Julie Bradbury  1967-02-12          Oxford
# ...            ...                      ...         ...             ...
# 145395      149118             Abbey Murphy  2002-04-14  Evergreen Park
# 145398      149121          Grace Zumwinkle  1999-04-23       Excelsior
# 145405      149128             Brian Cooper  1993-11-01       Anchorage
# 145418      149141              Nick Perbix  1998-06-15       Elk River
# 145427      149150            Jared Shumate  1999-03-06         Atlanta
#
#        born_region born_country            NOC  height_cm  weight_kg  \
# ...

# %%
bios[bios['born_country'].isin(["USA", "FRANCE","GBR"]) & (bios['name'].str.startswith("Keith"))]
# Out:
#         athlete_id                name   born_date             born_city  \
# 3505          3517       Keith Wallace  1961-03-29               Preston
# 12053        12118        Keith Hervey  1898-11-03                Fulham
# 14577        14674      Keith Harrison  1933-03-28            Birmingham
# 16166        16281      Keith Reynolds  1963-12-25              Solihull
# 18734        18862      Keith Sinclair  1945-06-26            Sunderland
# 29897        30123       Keith Langley  1961-06-03             Aldershot
# 34011        34275        Keith Remfry  1947-11-17                Ealing
# 46885        47234        Keith Collin  1937-01-18            Marylebone
# 50929        51288        Keith Carter  1924-08-30                 Akron
# 51185        51544       Keith Russell  1948-01-15                  Mesa
# 52913        53288      Keith Erickson  1944-04-19         San Francisco
# 55317        55712        Keith Boxell  1958-05-06               Clapham
# ...

# %%
#instead of using bios again and again we can use query
bios.query('born_country=="USA" and born_city=="Seattle"')
# Out:
#         athlete_id                   name   born_date born_city born_region  \
# 11030        11088          David Halpern  1955-08-18   Seattle  Washington
# 12800        12870            Todd Trewin  1958-04-20   Seattle  Washington
# 15476        15583         Scott McKinley  1968-10-15   Seattle  Washington
# 29079        29293            Joyce Tanac  1950-09-27   Seattle  Washington
# 31135        31371        Bill Kuhlemeier  1908-01-14   Seattle  Washington
# ...            ...                    ...         ...       ...         ...
# 133392      136331          Hans Struzyna  1989-03-31   Seattle  Washington
# 135448      138662  Maude Davis Crossland  2003-03-19   Seattle  Washington
# 136993      140229        Jenell Berhorst  2003-12-13   Seattle  Washington
# 143507      147159         Nevin Harrison  2002-06-02   Seattle  Washington
# 145446      149169       Corinne Stoddard  2001-08-15   Seattle  Washington
#
# ...

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
coffee['price']=4.99
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  price
# 0     Monday    Espresso          25   4.99
# 1     Monday       Latte          15   4.99
# 2    Tuesday    Espresso          30   4.99
# 3    Tuesday       Latte          20   4.99
# 4  Wednesday    Espresso          35   4.99

# %%
import numpy as np
coffee['new_price']=np.where(coffee['Coffee Type']=='Expresso',3.99,5.99)

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  new_price
# 0      Monday    Espresso          25       5.99
# 1      Monday       Latte          15       5.99
# 2     Tuesday    Espresso          30       5.99
# 3     Tuesday       Latte          20       5.99
# 4   Wednesday    Espresso          35       5.99
# 5   Wednesday       Latte          25       5.99
# 6    Thursday    Espresso          40       5.99
# 7    Thursday       Latte          30       5.99
# 8      Friday    Espresso          45       5.99
# 9      Friday       Latte          35       5.99
# 10   Saturday    Espresso          45       5.99
# 11   Saturday       Latte          35       5.99
# 12     Sunday    Espresso          45       5.99
# 13     Sunday       Latte          35       5.99

# %%
coffee.drop(columns=['price'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 coffee.drop(columns=['price'], inplace=True)
#
# File c:\Users\Parth\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
# ...

# %%
coffee_new=coffee.copy()

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  new_price
# 0      Monday    Espresso          25       5.99
# 1      Monday       Latte          15       5.99
# 2     Tuesday    Espresso          30       5.99
# 3     Tuesday       Latte          20       5.99
# 4   Wednesday    Espresso          35       5.99
# 5   Wednesday       Latte          25       5.99
# 6    Thursday    Espresso          40       5.99
# 7    Thursday       Latte          30       5.99
# 8      Friday    Espresso          45       5.99
# 9      Friday       Latte          35       5.99
# 10   Saturday    Espresso          45       5.99
# 11   Saturday       Latte          35       5.99
# 12     Sunday    Espresso          45       5.99
# 13     Sunday       Latte          35       5.99

# %%
coffee=coffee[['Day','Coffee Type', 'Units Sold', 'new_price']]

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  new_price
# 0      Monday    Espresso          25       5.99
# 1      Monday       Latte          15       5.99
# 2     Tuesday    Espresso          30       5.99
# 3     Tuesday       Latte          20       5.99
# 4   Wednesday    Espresso          35       5.99
# 5   Wednesday       Latte          25       5.99
# 6    Thursday    Espresso          40       5.99
# 7    Thursday       Latte          30       5.99
# 8      Friday    Espresso          45       5.99
# 9      Friday       Latte          35       5.99
# 10   Saturday    Espresso          45       5.99
# 11   Saturday       Latte          35       5.99
# 12     Sunday    Espresso          45       5.99
# 13     Sunday       Latte          35       5.99

# %%
coffee['revenue']=coffee['Units Sold']* coffee['new_price']

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  new_price  revenue
# 0      Monday    Espresso          25       5.99   149.75
# 1      Monday       Latte          15       5.99    89.85
# 2     Tuesday    Espresso          30       5.99   179.70
# 3     Tuesday       Latte          20       5.99   119.80
# 4   Wednesday    Espresso          35       5.99   209.65
# 5   Wednesday       Latte          25       5.99   149.75
# 6    Thursday    Espresso          40       5.99   239.60
# 7    Thursday       Latte          30       5.99   179.70
# 8      Friday    Espresso          45       5.99   269.55
# 9      Friday       Latte          35       5.99   209.65
# 10   Saturday    Espresso          45       5.99   269.55
# 11   Saturday       Latte          35       5.99   209.65
# 12     Sunday    Espresso          45       5.99   269.55
# 13     Sunday       Latte          35       5.99   209.65

# %%
coffee.rename(columns={'new_price':'price'}, inplace=True)

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  revenue
# 0      Monday    Espresso          25   5.99   149.75
# 1      Monday       Latte          15   5.99    89.85
# 2     Tuesday    Espresso          30   5.99   179.70
# 3     Tuesday       Latte          20   5.99   119.80
# 4   Wednesday    Espresso          35   5.99   209.65
# 5   Wednesday       Latte          25   5.99   149.75
# 6    Thursday    Espresso          40   5.99   239.60
# 7    Thursday       Latte          30   5.99   179.70
# 8      Friday    Espresso          45   5.99   269.55
# 9      Friday       Latte          35   5.99   209.65
# 10   Saturday    Espresso          45   5.99   269.55
# 11   Saturday       Latte          35   5.99   209.65
# 12     Sunday    Espresso          45   5.99   269.55
# 13     Sunday       Latte          35   5.99   209.65

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios_new=bios.copy()

# %%
#all string methods will start with .str
bios_new['first_name']=bios_new['name'].str.split(' ').str[0]

# %%
bios_new
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
bios_new.query('first_name=="Keith"')
# Out:
#         athlete_id               name   born_date     born_city  \
# 1897          1907       Keith Hanlon  1966-09-01           NaN
# 3505          3517      Keith Wallace  1961-03-29       Preston
# 6228          6255      Keith Hartley  1940-10-15     Vancouver
# 8898          8946        Keith Mwila  1966-01-01           NaN
# 12053        12118       Keith Hervey  1898-11-03        Fulham
# ...            ...                ...         ...           ...
# 99921       100722       Keith Carney  1970-02-03    Providence
# 102227      103168      Keith Beavers  1983-02-09        London
# 109900      111105  Keith Cumberpatch  1927-08-25  Christchurch
# 115973      117348    Keith Sanderson  1975-02-02      Plymouth
# 122121      124176     Keith Ferguson  1979-09-07          Sale
#
#              born_region born_country            NOC  height_cm  weight_kg  \
# 1897                 NaN          NaN        Ireland        NaN        NaN
# ...

# %%
bios_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   athlete_id    145500 non-null  int64
#  1   name          145500 non-null  object
#  2   born_date     143693 non-null  object
#  3   born_city     110908 non-null  object
#  4   born_region   110908 non-null  object
#  5   born_country  110908 non-null  object
#  6   NOC           145499 non-null  object
#  7   height_cm     106651 non-null  float64
#  8   weight_kg     102070 non-null  float64
#  9   died_date     33940 non-null   object
#  10  first_name    145500 non-null  object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 12.2+ MB

# %%
bios_new['born_datetime']=pd.to_datetime(bios_new['born_date'], format="%Y-%m-%d")

# %%
bios_new
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
bios_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 12 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   athlete_id     145500 non-null  int64
#  1   name           145500 non-null  object
#  2   born_date      143693 non-null  object
#  3   born_city      110908 non-null  object
#  4   born_region    110908 non-null  object
#  5   born_country   110908 non-null  object
#  6   NOC            145499 non-null  object
#  7   height_cm      106651 non-null  float64
#  8   weight_kg      102070 non-null  float64
#  9   died_date      33940 non-null   object
#  10  first_name     145500 non-null  object
#  11  born_datetime  143693 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(1), object(8)
# memory usage: 13.3+ MB

# %%
bios_new['born_year']=bios_new['born_datetime'].dt.year

# %%
bios_new[['name','born_year']]
# Out:
#                          name  born_year
# 0       Jean-François Blanchy     1886.0
# 1              Arnaud Boetsch     1969.0
# 2                Jean Borotra     1898.0
# 3             Jacques Brugnon     1895.0
# 4                Albert Canet     1878.0
# ...                       ...        ...
# 145495      Polina Luchnikova     2002.0
# 145496    Valeriya Merkusheva     1999.0
# 145497        Yuliya Smirnova     1998.0
# 145498         André Foussard     1899.0
# 145499          Bill Phillips     1913.0
#
# [145500 rows x 2 columns]

# %%
#sending the new dataframe to a csv file
bios_new.to_csv('./src/bios_new.csv', index=False)
#index= false prevents extra index to be stored

# %%
bios['height_category']=bios['height_cm'].apply(lambda x: 'short' if x<165 else ('Average' if x<185 else 'Tall'))

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date height_category
# 0  1960-10-02            Tall
# 1         NaN         Average
# 2  1994-07-17         Average
# 3  1978-03-20         Average
# 4  1930-07-25            Tall

# %%
coffee.loc[[0,1],'Units Sold']=np.nan
coffee.isna().sum()
# Out:
# Day            0
# Coffee Type    0
# Units Sold     2
# price          0
# revenue        0
# dtype: int64

# %%
coffee=coffee.fillna(1000)
print(coffee)
# Out:
#           Day Coffee Type  Units Sold  price  revenue
# 0      Monday    Espresso      1000.0   5.99   149.75
# 1      Monday       Latte      1000.0   5.99    89.85
# 2     Tuesday    Espresso        30.0   5.99   179.70
# 3     Tuesday       Latte        20.0   5.99   119.80
# 4   Wednesday    Espresso        35.0   5.99   209.65
# 5   Wednesday       Latte        25.0   5.99   149.75
# 6    Thursday    Espresso        40.0   5.99   239.60
# 7    Thursday       Latte        30.0   5.99   179.70
# 8      Friday    Espresso        45.0   5.99   269.55
# 9      Friday       Latte        35.0   5.99   209.65
# 10   Saturday    Espresso        45.0   5.99   269.55
# 11   Saturday       Latte        35.0   5.99   209.65
# 12     Sunday    Espresso        45.0   5.99   269.55
# 13     Sunday       Latte        35.0   5.99   209.65

# %%
coffee.fillna(coffee['Units Sold'].mean())
# Out:
#           Day Coffee Type  Units Sold  price  revenue
# 0      Monday    Espresso        35.0   5.99   149.75
# 1      Monday       Latte        35.0   5.99    89.85
# 2     Tuesday    Espresso        30.0   5.99   179.70
# 3     Tuesday       Latte        20.0   5.99   119.80
# 4   Wednesday    Espresso        35.0   5.99   209.65
# 5   Wednesday       Latte        25.0   5.99   149.75
# 6    Thursday    Espresso        40.0   5.99   239.60
# 7    Thursday       Latte        30.0   5.99   179.70
# 8      Friday    Espresso        45.0   5.99   269.55
# 9      Friday       Latte        35.0   5.99   209.65
# 10   Saturday    Espresso        45.0   5.99   269.55
# 11   Saturday       Latte        35.0   5.99   209.65
# 12     Sunday    Espresso        45.0   5.99   269.55
# 13     Sunday       Latte        35.0   5.99   209.65

# %%
coffee['Units Sold']=coffee['Units Sold'].interpolate()

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  revenue
# 0      Monday    Espresso         NaN   5.99   149.75
# 1      Monday       Latte         NaN   5.99    89.85
# 2     Tuesday    Espresso        30.0   5.99   179.70
# 3     Tuesday       Latte        20.0   5.99   119.80
# 4   Wednesday    Espresso        35.0   5.99   209.65
# 5   Wednesday       Latte        25.0   5.99   149.75
# 6    Thursday    Espresso        40.0   5.99   239.60
# 7    Thursday       Latte        30.0   5.99   179.70
# 8      Friday    Espresso        45.0   5.99   269.55
# 9      Friday       Latte        35.0   5.99   209.65
# 10   Saturday    Espresso        45.0   5.99   269.55
# 11   Saturday       Latte        35.0   5.99   209.65
# 12     Sunday    Espresso        45.0   5.99   269.55
# 13     Sunday       Latte        35.0   5.99   209.65

# %%
coffee.dropna() 
#dropping the rows having null values in their columns
# Out:
#           Day Coffee Type  Units Sold  price  revenue
# 2     Tuesday    Espresso        30.0   5.99   179.70
# 3     Tuesday       Latte        20.0   5.99   119.80
# 4   Wednesday    Espresso        35.0   5.99   209.65
# 5   Wednesday       Latte        25.0   5.99   149.75
# 6    Thursday    Espresso        40.0   5.99   239.60
# 7    Thursday       Latte        30.0   5.99   179.70
# 8      Friday    Espresso        45.0   5.99   269.55
# 9      Friday       Latte        35.0   5.99   209.65
# 10   Saturday    Espresso        45.0   5.99   269.55
# 11   Saturday       Latte        35.0   5.99   209.65
# 12     Sunday    Espresso        45.0   5.99   269.55
# 13     Sunday       Latte        35.0   5.99   209.65

# %%
coffee[coffee['Units Sold'].notna()]
# Out:
#           Day Coffee Type  Units Sold  price  revenue
# 2     Tuesday    Espresso        30.0   5.99   179.70
# 3     Tuesday       Latte        20.0   5.99   119.80
# 4   Wednesday    Espresso        35.0   5.99   209.65
# 5   Wednesday       Latte        25.0   5.99   149.75
# 6    Thursday    Espresso        40.0   5.99   239.60
# 7    Thursday       Latte        30.0   5.99   179.70
# 8      Friday    Espresso        45.0   5.99   269.55
# 9      Friday       Latte        35.0   5.99   209.65
# 10   Saturday    Espresso        45.0   5.99   269.55
# 11   Saturday       Latte        35.0   5.99   209.65
# 12     Sunday    Espresso        45.0   5.99   269.55
# 13     Sunday       Latte        35.0   5.99   209.65

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date height_category
# 0  1960-10-02            Tall
# 1         NaN         Average
# 2  1994-07-17         Average
# 3  1978-03-20         Average
# 4  1930-07-25            Tall

# %%
bios['born_city'].value_counts()
# Out:
# born_city
# Budapest           1378
# Moskva (Moscow)     883
# Oslo                708
# Stockholm           629
# Praha (Prague)      600
#                    ...
# Bodrogkisfalud        1
# Ternberg              1
# Klaus                 1
# Plaški                1
# Dulwich Hill          1
# Name: count, Length: 22368, dtype: int64

# %%
bios[bios['born_country']=="USA"]['born_region'].value_counts().tail()
# Out:
# born_region
# South Dakota     27
# West Virginia    24
# Delaware         22
# North Dakota     16
# Wyoming          14
# Name: count, dtype: int64

# %%
bios
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  revenue  yesterday_revenue  \
# 0      Monday    Espresso         NaN   5.99   149.75                NaN
# 1      Monday       Latte         NaN   5.99    89.85                NaN
# 2     Tuesday    Espresso        30.0   5.99   179.70             149.75
# 3     Tuesday       Latte        20.0   5.99   119.80              89.85
# 4   Wednesday    Espresso        35.0   5.99   209.65             179.70
# 5   Wednesday       Latte        25.0   5.99   149.75             119.80
# 6    Thursday    Espresso        40.0   5.99   239.60             209.65
# 7    Thursday       Latte        30.0   5.99   179.70             149.75
# 8      Friday    Espresso        45.0   5.99   269.55             239.60
# 9      Friday       Latte        35.0   5.99   209.65             179.70
# 10   Saturday    Espresso        45.0   5.99   269.55             269.55
# 11   Saturday       Latte        35.0   5.99   209.65             209.65
# ...

# %%
coffee.groupby(['Coffee Type'])['Units Sold'].sum()
# Out:
# Coffee Type
# Espresso    240.0
# Latte       180.0
# Name: Units Sold, dtype: float64

# %%
coffee.groupby(['Coffee Type'])['Units Sold'].mean()
# Out:
# Coffee Type
# Espresso    40.0
# Latte       30.0
# Name: Units Sold, dtype: float64

# %%
coffee['yesterday_revenue']=coffee['revenue'].shift(2)

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  revenue  yesterday_revenue  \
# 0      Monday    Espresso         NaN   5.99   149.75                NaN
# 1      Monday       Latte         NaN   5.99    89.85                NaN
# 2     Tuesday    Espresso        30.0   5.99   179.70             149.75
# 3     Tuesday       Latte        20.0   5.99   119.80              89.85
# 4   Wednesday    Espresso        35.0   5.99   209.65             179.70
# 5   Wednesday       Latte        25.0   5.99   149.75             119.80
# 6    Thursday    Espresso        40.0   5.99   239.60             209.65
# 7    Thursday       Latte        30.0   5.99   179.70             149.75
# 8      Friday    Espresso        45.0   5.99   269.55             239.60
# 9      Friday       Latte        35.0   5.99   209.65             179.70
# 10   Saturday    Espresso        45.0   5.99   269.55             269.55
# 11   Saturday       Latte        35.0   5.99   209.65             209.65
# ...

# %%
coffee['pct_change']=(coffee['revenue']/coffee['yesterday_revenue'])*100

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  revenue  yesterday_revenue  \
# 0      Monday    Espresso         NaN   5.99   149.75                NaN
# 1      Monday       Latte         NaN   5.99    89.85                NaN
# 2     Tuesday    Espresso        30.0   5.99   179.70             149.75
# 3     Tuesday       Latte        20.0   5.99   119.80              89.85
# 4   Wednesday    Espresso        35.0   5.99   209.65             179.70
# 5   Wednesday       Latte        25.0   5.99   149.75             119.80
# 6    Thursday    Espresso        40.0   5.99   239.60             209.65
# 7    Thursday       Latte        30.0   5.99   179.70             149.75
# 8      Friday    Espresso        45.0   5.99   269.55             239.60
# 9      Friday       Latte        35.0   5.99   209.65             179.70
# 10   Saturday    Espresso        45.0   5.99   269.55             269.55
# 11   Saturday       Latte        35.0   5.99   209.65             209.65
# ...

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date height_category
# 0  1960-10-02            Tall
# 1         NaN         Average
# 2  1994-07-17         Average
# 3  1978-03-20         Average
# 4  1930-07-25            Tall

# %%
bios['height_rank']=bios['height_cm'].rank()

# %%
bios
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
bios.sort_values(['height_rank'], ascending=False)
# Out:
#         athlete_id                   name   born_date           born_city  \
# 89070        89782               Yao Ming  1980-09-12      Xuhui District
# 5781          5804         Tommy Burleson  1952-02-24           Crossnore
# 6978          7013        Arvydas Sabonis  1964-12-19              Kaunas
# 89075        89787         Roberto Dueñas  1975-11-01              Madrid
# 120266      122147           Zhang Zhaoxu  1987-11-18             Binzhou
# ...            ...                    ...         ...                 ...
# 145490      149217            Sin Ye-Chan  1995-06-13                 NaN
# 145491      149218          Matthew Wepke  1989-12-05                 NaN
# 145492      149219  Carlos García-Ordóñez  1927-04-24  La Habana (Havana)
# 145493      149220     Landysh Falyakhova  1998-08-31    Dva Polya Artash
# 145499      149814          Bill Phillips  1913-07-15        Dulwich Hill
#
#                  born_region born_country                         NOC  \
# ...

# %%
coffee.select_dtypes('float64').cumsum().reset_index()
# Out:
#     index  Units Sold  price  revenue  yesterday_revenue   pct_change
# 0       0         NaN   5.99   149.75                NaN          NaN
# 1       1         NaN  11.98   239.60                NaN          NaN
# 2       2        30.0  17.97   419.30             149.75   120.000000
# 3       3        50.0  23.96   539.10             239.60   253.333333
# 4       4        85.0  29.95   748.75             419.30   370.000000
# 5       5       110.0  35.94   898.50             539.10   495.000000
# 6       6       150.0  41.93  1138.10             748.75   609.285714
# 7       7       180.0  47.92  1317.80             898.50   729.285714
# 8       8       225.0  53.91  1587.35            1138.10   841.785714
# 9       9       260.0  59.90  1797.00            1317.80   958.452381
# 10     10       305.0  65.89  2066.55            1587.35  1058.452381
# 11     11       340.0  71.88  2276.20            1797.00  1158.452381
# ...
